# %% [markdown]
# f(x) = -12x^4*sin(cos(x)) - 18x^3+5x^2 + 10x - 30
#
# 1. Определить корни
#
# 2. Найти интервалы, на которых функция возрастает
#
# 3. Найти интервалы, на которых функция убывает
#
# 4. Построить график
#
# 5. Вычислить вершину
#
# 6. Определить промежутки, на котором f > 0
#
# 7. Определить промежутки, на котором f < 0
#
# (Форма с ответами - внизу :))

# %%
import sympy
from sympy.plotting import plot

# %%
x = sympy.Symbol('x')

# %%
f_x = -12 * x**4 * sympy.sin(sympy.cos(x)) - 18* x**3 + 5 * x**2 + 10 * x - 30
print(f_x)
# Out:
# -12*x**4*sin(cos(x)) - 18*x**3 + 5*x**2 + 10*x - 30

# %%
print(f_x.subs(x, 10.0))
# Out:
# 71852.7695124845

# %%
plot(f_x)

# %%
diff_f_x = sympy.diff(f_x, x)
print(diff_f_x)
# Out:
# 12*x**4*sin(x)*cos(cos(x)) - 48*x**3*sin(cos(x)) - 54*x**2 + 10*x + 10

# %%
for i in range(-76506230, -76506220):
    print(i / 10000000, f_x.subs(x, i / 10000000)) # Поиск промежутка для первого корня
# Out:
# -7.650623 0.0274237733701739
# -7.6506229 0.0235875665712229
# -7.6506228 0.0197513603379775
# -7.6506227 0.0159151547049987
# -7.6506226 0.0120789495977078
# -7.6506225 0.00824274505794165
# -7.6506224 0.00440654108024319
# -7.6506223 0.000570337702811230
# -7.6506222 -0.00326586514711380
# -7.6506221 -0.00710206742951414

# %%
print(f_x.subs(x, -7.6506240))
print(f_x.subs(x, -7.6506223))
print(f_x.subs(x, -7.6506210))
# Out:
# 0.0657858722606761
# 0.000570337702811230
# -0.0493002551611426

# %%
for i in range(50268650, 50268663):
    print(i / 10000000, f_x.subs(x, -i / 10000000)) # Поиск промежутка для второго корня
# Out:
# 5.026865 0.00686143023631303
# 5.0268651 0.00612221653773304
# 5.0268652 0.00538300277275994
# 5.0268653 0.00464378892866080
# 5.0268654 0.00390457501316632
# 5.0268655 0.00316536102491227
# 5.0268656 0.00242614697071986
# 5.0268657 0.00168693283785615
# 5.0268658 0.000947718631778116
# 5.0268659 0.000208504360671213
# 5.026866 -0.000530709989561728
# 5.0268661 -0.00126992441119000
# 5.0268662 -0.00200913889966614

# %%
print(f_x.subs(x, -5.026870))
print(f_x.subs(x, -5.026866))
print(f_x.subs(x, -5.026850))
# Out:
# -0.0300993432229006
# -0.000530709989561728
# 0.117742665542210

# %%
for i in range(133896663927710820, 133896663927710850):
    print(i / 100000000000000000, f_x.subs(x, -i / 100000000000000000)) # Поиск промежутка для третьего корня
# Out:
# 1.3389666392771082 -1.06581410364015e-14
# 1.3389666392771082 -1.06581410364015e-14
# 1.3389666392771082 -1.06581410364015e-14
# 1.3389666392771082 -1.06581410364015e-14
# 1.3389666392771082 -1.06581410364015e-14
# 1.3389666392771082 -1.06581410364015e-14
# 1.3389666392771082 -1.06581410364015e-14
# 1.3389666392771082 -1.06581410364015e-14
# 1.3389666392771082 -1.06581410364015e-14
# 1.3389666392771082 -1.06581410364015e-14
# 1.3389666392771082 -1.06581410364015e-14
# 1.3389666392771082 -1.06581410364015e-14
# 1.3389666392771082 -1.06581410364015e-14
# 1.3389666392771082 -1.06581410364015e-14
# 1.3389666392771082 -1.06581410364015e-14
# 1.3389666392771082 -1.06581410364015e-14
# 1.3389666392771085 7.10542735760100e-15
# 1.3389666392771085 7.10542735760100e-15
# 1.3389666392771085 7.10542735760100e-15
# 1.3389666392771085 7.10542735760100e-15
# 1.3389666392771085 7.10542735760100e-15
# 1.3389666392771085 7.10542735760100e-15
# 1.3389666392771085 7.10542735760100e-15
# ...

# %%
print(f_x.subs(x, -1.3389666392771090))
print(f_x.subs(x, -1.3389666392771082))
print(f_x.subs(x, -1.3389666392771070))
# Out:
# 6.57252030578093e-14
# -1.06581410364015e-14
# -1.63424829224823e-13

# %%
for i in range(2273050, 2273060):
    print(i / 1000000, f_x.subs(x, i / 1000000)) # Поиск промежутка для четвёртого корня
# Out:
# 2.27305 -0.00197391671267155
# 2.273051 -0.00168557687200632
# 2.273052 -0.00139723640933198
# 2.273053 -0.00110889532450642
# 2.273054 -0.000820553617700170
# 2.273055 -0.000532211288884810
# 2.273056 -0.000243868337975073
# 2.273057 4.44752350574618e-5
# 2.273058 0.000332819429928577
# 2.273059 0.000621164246979333

# %%
print(f_x.subs(x, 2.273065))
print(f_x.subs(x, 2.273056))
print(f_x.subs(x, 2.273050))
# Out:
# 0.00235124621221416
# -0.000243868337975073
# -0.00197391671267155

# %%
for i in range(4383520, 4383530):
    tmp = 1000000
    print(i / tmp, f_x.subs(x, i / tmp)) # Поиск промежутка для пятого корня
# Out:
# 4.38352 0.0135975870559832
# 4.383521 0.00992055784922741
# 4.383522 0.00624351918395405
# 4.383523 0.00256647105925367
# 4.383524 -0.00111058652419160
# 4.383525 -0.00478765356297117
# 4.383526 -0.00846473006436099
# 4.383527 -0.0121418160242683
# 4.383528 -0.0158189114438301
# 4.383529 -0.0194960163219093

# %%
print(f_x.subs(x, 4.383525))
print(f_x.subs(x, 4.383524))
print(f_x.subs(x, 4.383520))
# Out:
# -0.00478765356297117
# -0.00111058652419160
# 0.0135975870559832

# %%
for i in range(8035160, 8035170):
    tmp = 1000000
    print(i / tmp, f_x.subs(x, i / tmp)) # Поиск промежутка для шестого корня
# Out:
# 8.03516 -0.204492953413137
# 8.035161 -0.155019860843822
# 8.035162 -0.105546736900578
# 8.035163 -0.0560735814069631
# 8.035164 -0.00660039453578065
# 8.035165 0.0428728237930045
# 8.035166 0.0923460736721609
# 8.035167 0.141819354923427
# 8.035168 0.191292667725065
# 8.035169 0.240766011900632

# %%
print(f_x.subs(x, 8.035170))
print(f_x.subs(x, 8.035164))
print(f_x.subs(x, 8.035160))
# Out:
# 0.290239387622933
# -0.00660039453578065
# -0.204492953413137

# %%
diff_f_x = sympy.diff(f_x, x)
print(diff_f_x)
# Out:
# 12*x**4*sin(x)*cos(cos(x)) - 48*x**3*sin(cos(x)) - 54*x**2 + 10*x + 10

# %%
plot(diff_f_x)

# %%
for i in range(-997895380, -997895370):
    print(i / 100000000, diff_f_x.subs(x, i / 100000000)) # Поиск вершины 1
# Out:
# -9.9789538 0.00439647112216335
# -9.97895379 0.00326873453013832
# -9.97895378 0.00214099777076626
# -9.97895377 0.00101326122239698
# -9.97895376 -0.000114475507871248
# -9.97895375 -0.00124221201258479
# -9.97895374 -0.00236994870647322
# -9.97895373 -0.00349768516025506
# -9.97895372 -0.00462542182503967
# -9.97895371 -0.00575315825699363

# %%
print(f_x.subs(x, -9.97895390))
print(f_x.subs(x, -9.97895376))
print(f_x.subs(x, -9.97895350)) # Проверка вершины 1
# Out:
# 107678.041644002
# 107678.041644003
# 107678.041643999

# %%
for i in range(-6831380, -6831360):
    print(i / 1000000, diff_f_x.subs(x, i / 1000000)) # Поиск вершины 2
# Out:
# -6.83138 -0.260752805595985
# -6.831379 -0.234572553817998
# -6.831378 -0.208392357617413
# -6.831377 -0.182212216997868
# -6.831376 -0.156032131955726
# -6.831375 -0.129852102512814
# -6.831374 -0.103672128618200
# -6.831373 -0.0774922103046265
# -6.831372 -0.0513123475757311
# -6.831371 -0.0251325404187810
# -6.83137 0.00104721115894790
# -6.831369 0.0272269071574556
# -6.831368 0.0534065475585521
# -6.831367 0.0795861324040743
# -6.831366 0.105765661672194
# -6.831365 0.131945135370188
# -6.831364 0.158124553476227
# -6.831363 0.184303916019417
# -6.831362 0.210483222954281
# -6.831361 0.236662474335390

# %%
print(f_x.subs(x, -6.831371))
print(f_x.subs(x, -6.83137))
print(f_x.subs(x, -6.831369)) # Проверка вершины 2
# Out:
# -13820.5349264607
# -13820.5349264727
# -13820.5349264586

# %%
for i in range(-41677840, -41677830):
    print(i / 10000000, diff_f_x.subs(x, i / 10000000)) # Поиск вершины 3
# Out:
# -4.167784 0.00305075785672670
# -4.1677839 0.00241004338522544
# -4.1677838 0.00176932902422777
# -4.1677837 0.00112861478010018
# -4.1677836 0.000487900640564476
# -4.1677835 -0.000152813388467621
# -4.1677834 -0.000793527301539143
# -4.1677833 -0.00143424110865453
# -4.1677832 -0.00207495480526632
# -4.1677831 -0.00271566838591752

# %%
print(f_x.subs(x, -4.16778340))
print(f_x.subs(x, -4.1677835))
print(f_x.subs(x, -4.1677830)) # Проверка вершины 3
# Out:
# 3111.36323873591
# 3111.36323873596
# 3111.36323873508

# %%
for i in range(-39270, -39260):
    print(i / 100000, diff_f_x.subs(x, i / 100000)) # Поиск вершины 4
# Out:
# -0.3927 -0.000826648428119206
# -0.39269 -0.000464399646122493
# -0.39268 -0.000102154780325381
# -0.39267 0.000260086169241225
# -0.39266 0.000622323202554578
# -0.39265 0.000984556319583357
# -0.39264 0.00134678552029845
# -0.39263 0.00170901080466898
# -0.39262 0.00207123217266722
# -0.39261 0.00243344962426675

# %%
print(f_x.subs(x, -0.39270))
print(f_x.subs(x, -0.39268))
print(f_x.subs(x, -0.39251)) # Проверка вершины 4
# Out:
# -32.2935799270248
# -32.2935799363128
# -32.2935794302702

# %%
for i in range(45450, 45460):
    print(i / 100000, diff_f_x.subs(x, i / 100000)) # Поиск вершины 5
# Out:
# 0.4545 0.00438004041887768
# 0.45451 0.00378472422539416
# 0.45452 0.00318939042192926
# 0.45453 0.00259403900853133
# 0.45454 0.00199866998526049
# 0.45455 0.00140328335217221
# 0.45456 0.000807879109317428
# 0.45457 0.000212457256759363
# 0.45458 -0.000382982205452104
# 0.45459 -0.000978439277261295

# %%
print(f_x.subs(x, 0.45461))
print(f_x.subs(x, 0.45457))
print(f_x.subs(x, 0.45450)) # Проверка вершины 5
# Out:
# -26.5127224045539
# -26.5127223654158
# -26.5127225261583

# %%
for i in range(1700600, 1700610):
    print(i / 1000000, diff_f_x.subs(x, i / 1000000)) # Поиск вершины 6
# Out:
# 1.7006 -0.00231971183046653
# 1.700601 -0.00200098294533291
# 1.700602 -0.00168225324810578
# 1.700603 -0.00136352273864304
# 1.700604 -0.00104479141712943
# 1.700605 -0.000726059283365998
# 1.700606 -0.000407326337395375
# 1.700607 -8.85925792744047e-5
# 1.700608 0.000230141990996913
# 1.700609 0.000548877373518053

# %%
print(f_x.subs(x, 1.700610))
print(f_x.subs(x, 1.700608))
print(f_x.subs(x, 1.700600)) # Проверка вершины 6
# Out:
# -74.1062930849279
# -74.1062930860256
# -74.1062930776673

# %%
for i in range(38193100, 38193110):
    print(i / 10000000, diff_f_x.subs(x, i / 10000000)) # Поиск вершины 7
# Out:
# 3.81931 0.00286175917040055
# 3.8193101 0.00251836860229560
# 3.8193102 0.00217497793687471
# 3.8193103 0.00183158717049992
# 3.8193104 0.00148819630749131
# 3.8193105 0.00114480534534778
# 3.8193106 0.000801414283614577
# 3.8193107 0.000458023125247564
# 3.8193108 0.000114631867745629
# 3.8193109 -0.000228759489573349

# %%
print(f_x.subs(x, 3.8193110))
print(f_x.subs(x, 3.8193108))
print(f_x.subs(x, 3.8193100)) # Проверка вершины 7
# Out:
# 872.255770291014
# 872.255770291059
# 872.255770289869

# %%
for i in range(700103160, 700103170):
    print(i / 100000000, diff_f_x.subs(x, i / 100000000)) # Поиск вершины 8
# Out:
# 7.0010316 -0.00202581394296431
# 7.00103161 -0.00167976320335583
# 7.00103162 -0.00133371246374736
# 7.00103163 -0.000987661715043942
# 7.00103164 -0.000641610949969618
# 7.00103165 -0.000295560190352262
# 7.00103166 5.04905747220619e-5
# 7.00103167 0.000396541361624259
# 7.00103168 0.000742592141250498
# 7.00103169 0.00108864292633370

# %%
print(f_x.subs(x, 7.00103175))
print(f_x.subs(x, 7.00103165))
print(f_x.subs(x, 7.00103150)) # Проверка вершины 8
# Out:
# -25610.5096810329
# -25610.5096810330
# -25610.5096810326

# %%
for i in range(9877149050, 9877149060):
    print(i / 1000000000, diff_f_x.subs(x, i / 1000000000)) # Поиск вершины 9
# Out:
# 9.87714905 0.000382120237190975
# 9.877149051 0.000285924608760979
# 9.877149052 0.000189728987606941
# 9.877149053 9.35333664529026e-5
# 9.877149054 -2.66225833911449e-6
# 9.877149055 -9.88578940450680e-5
# 9.877149056 -0.000195053504285170
# 9.877149057 -0.000291249136353144
# 9.877149058 -0.000387444757507183
# 9.877149059 -0.000483640375023242

# %%
print(f_x.subs(x, 9.877149090))
print(f_x.subs(x, 9.877149052))
print(f_x.subs(x, 9.877149020)) # Проверка вершины 9
# Out:
# 72634.6640656332
# 72634.6640656333
# 72634.6640656332

# %% [markdown]
# Ответы:
#
# f(x) = -12x^4*sin(cos(x)) - 18x^3+5x^2 + 10x - 30
#
# 1. Определить корни
#
# * Промежуток для первого корня: -7.6506223:-7.6506222;
# * Промежуток для второго корня: 5.0268659:5.026866
# * Промежуток для третьего корня: 1.3389666392771082:1.3389666392771085
# * Промежуток для четвёртого корня: 2.273056:2.273058
# * Промежуток для пятого корня: 4.383523:4.383524
# * Промежуток для шестого корня: 8.035164:8.035165
#
# 2. Найти интервалы, на которых функция возрастает
#
# Первый интервал: -6.83137:-4.1677835, второй интервал: -0.39268:0.45457, третий интервал: 1.700608:3.8193108, четвёртый интервал: 7.00103165:9.877149052
#
# 3. Найти интервалы, на которых функция убывает
#
# Первый интервал: -9.97895376:-6.83137, второй интервал: -4.1677835:-0.39268, третий интервал: 0.45457:1.700608, четвёртый интервал: 3.8193108:7.00103165,
#
# 4. Построить график
#
# 5. Вычислить вершину
#
# Вершина 1: -9.97895376, Вершина 2: -6.83137, Вершина 3: -4.1677835, Вершина 4: -0.39268, Вершина 5: 0.45457, Вершина 6: 1.700608, Вершина 7: 3.8193108, Вершина 8: 7.00103165, Вершина 9: 9.877149052
#
# 6. Определить промежутки, на котором f > 0
#
# * Промежуток 1: +оо:-7.6506223;
# * Промежуток 2: -5.026866:-1.3389666392771082;
# * Промежуток 3: 2.273056:4.383524;
# * Промежуток 4: 8.035164:+оо.
#
# 7. Определить промежутки, на котором f < 0
#
# * Промежуток 1: -7.6506223:-5.026866;
# * Промежуток 2: -1.3389666392771082:2.273056;
# * Промежуток 3: 4.383524:8.035164.
